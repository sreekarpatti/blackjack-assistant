# %% [markdown]
# # Training Curves
# Load logged metrics and plot reward / EV over time.

# %%
import matplotlib.pyplot as plt
steps = [0, 500000, 1000000]
ev = [0.0, 0.02, 0.05]
plt.plot(steps, ev)
plt.title('Sample EV Curve')
plt.xlabel('Timesteps')
plt.ylabel('EV')
plt.show()
