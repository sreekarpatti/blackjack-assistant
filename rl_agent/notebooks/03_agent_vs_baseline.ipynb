# %% [markdown]
# # PPO vs Baseline
# Run head-to-head evaluation summary.

# %%
from rl_agent.training.evaluate import evaluate_model
# update model path before running
# metrics = evaluate_model('rl_agent/models/best_model.zip', 'rl_agent/config.yaml', episodes=1000)
# metrics
