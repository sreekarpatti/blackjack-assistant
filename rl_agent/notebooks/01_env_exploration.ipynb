# %% [markdown]
# # Environment Exploration
# Inspect one episode step-by-step.

# %%
from rl_agent.environment.blackjack_env import BlackjackEnv
env = BlackjackEnv()
obs, info = env.reset()
obs, info
